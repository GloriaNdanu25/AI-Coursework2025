# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxwell-Gitonga/AI-Coursework2025/blob/main/Netflix_Titles_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
import pandas as pd
import numpy as np
from IPython.display import display, Markdown

# %%
#2
from google.colab import files
uploaded = files.upload()

filename = next(iter(uploaded))
df = pd.read_csv(filename)
print("Loaded:", filename)
# Out:
#      <input type="file" id="files-60be5cba-fb03-4db1-8138-aebab9683c7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-60be5cba-fb03-4db1-8138-aebab9683c7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#3
print("shape (rows, cols):", df.shape)
display(df.head(5))
print("\nData types:")
display(df.dtypes)
print("\nInfo:")
df.info()
# Out:
# shape (rows, cols): (8807, 12)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#4
print("Missing values per column:")
display(df.isnull().sum())
# Out:
# Missing values per column:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#5
last20 = df.tail(20)


type_counts = last20['type'].value_counts()

print("What type is it among the last 20 rows:")
print(type_counts)
# Out:
# What type is it among the last 20 rows:
# type
# Movie      15
# TV Show     5
# Name: count, dtype: int64

# %%
#6
import pandas as pd

# %%
#7
from google.colab import files
uploaded = files.upload()

filename = next(iter(uploaded))
df = pd.read_csv(filename)
print("Loaded:", filename)
# Out:
#      <input type="file" id="files-e297fffb-4b41-4d49-a3e6-60981662da3b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e297fffb-4b41-4d49-a3e6-60981662da3b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#8
import pandas as pd

df = pd.read_csv('netflix_titles (1).csv')
print(df.shape)
df.head()
# Out:
# (8807, 12)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#9
num_sa_movies = df[(df['country'].str.contains('South Africa', na=False)) & (df['type'] == 'Movie')].shape[0]
num_sa_tvshows = df[(df['country'].str.contains('South Africa', na=False)) & (df['type'] == 'TV Show')].shape[0]


print("Number of Movies from South Africa:", num_sa_movies)
print("Mumber of Tv Shows from South Africa:", num_sa_tvshows)
# Out:
# Number of Movies from South Africa: 51
# Mumber of Tv Shows from South Africa: 11

# %%
#10
print(df.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#11
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()

filename = next(iter(uploaded))
df = pd.read_csv(filename)
print("Loaded:", filename)
# Out:
#      <input type="file" id="files-1cc28484-8db0-4582-89a0-3b7c5e5005e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1cc28484-8db0-4582-89a0-3b7c5e5005e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('netflix_titles (1).csv')
print(df.shape)
df.head()
# Out:
# (8807, 12)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#12
desc_row12 = df.iloc[11]['description']
print("Description of movie in 12th row:", desc_row12)
# Out:
# Description of movie in 12th row: Struggling to earn a living in Bangkok, a man joins an emergency rescue service and realizes he must unravel a citywide conspiracy.

# %%
#13
import pandas as pd
df = pd.read_csv('netflix_titles (1).csv')
sa_movies = df[(df['country'].str.contains('South Africa', na=False)) & (df['type'] == 'Movie')]
sa_2021 = sa_movies[sa_movies['release_year'] == 2021]
print(sa_2021[['show_id','title', 'release_year']])
# Out:
#      show_id                         title  release_year
# 293     s294                          Slay          2021
# 764     s765  Trippin' with the Kandasamys          2021
# 881     s882                I Am All Girls          2021
# 1172   s1173       Loyiso Gola: Unlearning          2021

# %%
#14
movies_2021 = df[(df['type'] == 'Movie') & (df['release_year'] == 2021)]
print(movies_2021[['title', 'cast']])
# Out:
#                                                   title  \
# 6                      My Little Pony: A New Generation
# 9                                          The Starling
# 12                                         Je Suis Karl
# 13                     Confessions of an Invisible Girl
# 18                                            Intrusion
# ...                                                 ...
# 1425                        Creating The Queen's Gambit
# 1431                                        Stuck Apart
# 1436  Ratones Paranoicos: The Band that Rocked Argen...
# 1466                       The Minimalists: Less Is Now
# 1468                          What Happened to Mr. Cha?
#
#                                                    cast
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 13    Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# ...
