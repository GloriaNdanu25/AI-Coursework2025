# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxwell-Gitonga/AI-Coursework2025/blob/main/Airplane_Crashes_and_Fatalities_sincse_1908_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from IPython.display import display, Markdown

# %%
from google.colab import files
uploaded = files.upload()

filename = next(iter(uploaded))
df = pd.read_csv(filename)
print("Loaded:", filename)
# Out:
#      <input type="file" id="files-eacba39f-2aaa-4d1b-9fdc-35c82dcf9119" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eacba39f-2aaa-4d1b-9fdc-35c82dcf9119">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Number 5
fatality_locations=df[['Date','Location','Aboard','Fatalities']]

# %%
#Test
fatality_locations.head(4)
# Out:
#          Date                            Location  Aboard  Fatalities
# 0  09/17/1908                 Fort Myer, Virginia     2.0         1.0
# 1  07/12/1912             AtlantiCity, New Jersey     5.0         5.0
# 2  08/06/1913  Victoria, British Columbia, Canada     1.0         1.0
# 3  09/09/1913                  Over the North Sea    20.0        14.0

# %%
#Number 7 (i)Compare the number of passengers aboard to the number of fatalities per crash.
fatality_locations[['Aboard', 'Fatalities']].head(10)
# Out:
#    Aboard  Fatalities
# 0     2.0         1.0
# 1     5.0         5.0
# 2     1.0         1.0
# 3    20.0        14.0
# 4    30.0        30.0
# 5    41.0        21.0
# 6    19.0        19.0
# 7    20.0        20.0
# 8    22.0        22.0
# 9    19.0        19.0

# %%
#Number 7 (ii)Are there any recorded crashes where there were no fatalities? If so, how many?
no_fatalities=fatality_locations[fatality_locations['Fatalities']==0]
num_no_of_fatalities=len(no_fatalities)
print("Number of crashes with no fatalities:", num_no_of_fatalities)
# Out:
# Number of crashes with no fatalities: 58

# %%
from IPython.display import Image, display
from google.colab import files
uploaded = files.upload()
display(Image(list(uploaded.keys())[0]))
# Out:
#      <input type="file" id="files-ab735ff8-5a0e-456d-b6ca-ee1c02968c63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab735ff8-5a0e-456d-b6ca-ee1c02968c63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
